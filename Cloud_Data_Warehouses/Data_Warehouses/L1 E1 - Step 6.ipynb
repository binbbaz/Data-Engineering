# %% [markdown]
# # STEP 6: Repeat the computation from the facts & dimension table
#
# Note: You will not have to write any code in this notebook. It's purely to illustrate the performance difference between Star and 3NF schemas.
#
# Start by running the code in the cell below to connect to the database.

# %%
# !PGPASSWORD=root createdb -h 127.0.0.1 -U abbas pagila_star
# !PGPASSWORD=root psql -q -h 127.0.0.1 -U abbas -d pagila_star -f Data/pagila/pagila-star.sql

# %%
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'abbas'
DB_PASSWORD = 'root'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://abbas:root@127.0.0.1:5432/pagila_star
# 'Connected: abbas@pagila_star'

# %% [markdown]
# ## 6.1 Facts Table has all the needed dimensions, no need for deep joins

# %%
# %%time
# %%sql
SELECT movie_key, date_key, customer_key, sales_amount
FROM factSales 
limit 5;

# %% [markdown]
# ## 6.2 Join fact table with dimensions to replace keys with attributes
#
# As you run each cell, pay attention to the time that is printed. Which schema do you think will run faster?
#
# ##### Star Schema

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
FROM factSales 
JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
group by (dimMovie.title, dimDate.month, dimCustomer.city)
order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc;

# %% [markdown]
# ##### 3NF Schema

# %%
# %%time
# %%sql
SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue
FROM payment p
JOIN rental r    ON ( p.rental_id = r.rental_id )
JOIN inventory i ON ( r.inventory_id = i.inventory_id )
JOIN film f ON ( i.film_id = f.film_id)
JOIN customer c  ON ( p.customer_id = c.customer_id )
JOIN address a ON ( c.address_id = a.address_id )
JOIN city ci ON ( a.city_id = ci.city_id )
group by (f.title, month, ci.city)
order by f.title, month, ci.city, revenue desc;
# Out:
#  * postgresql://abbas:***@127.0.0.1:5432/pagila_star
# 15994 rows affected.
# CPU times: user 11.8 ms, sys: 3.36 ms, total: 15.2 ms
# Wall time: 849 ms
# [('ACADEMY DINOSAUR', 1.0, 'Celaya', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 1.0, 'Cianjur', Decimal('11.94')),
#  ('ACADEMY DINOSAUR', 2.0, 'San Lorenzo', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 2.0, 'Sullana', Decimal('11.94')),
#  ('ACADEMY DINOSAUR', 2.0, 'Udaipur', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Almirante Brown', Decimal('11.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Goinia', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Kaliningrad', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Kurashiki', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Livorno', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Nukualofa', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Rajkot', Decimal('23.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Sivas', Decimal('23.94')),
#  ('ACADEMY DINOSAUR', 3.0, 'Tabriz', Decimal('23.94')),
#  ('ACADEMY DINOSAUR', 4.0, 'Charlotte Amalie', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 4.0, 'Lipetsk', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 4.0, 'London', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 4.0, 'Pjatigorsk', Decimal('11.94')),
#  ('ACADEMY DINOSAUR', 4.0, 'Sucre', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 4.0, 'Tel Aviv-Jaffa', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 5.0, 'Hamilton', Decimal('5.94')),
#  ('ACADEMY DINOSAUR', 5.0, 'Jos Azueta', Decimal('11.94')),
#  ('ACADEMY DINOSAUR', 5.0, 'Vila Velha', Decimal('5.94')),
#  ('ACE GOLDFINGER', 3.0, 'Binzhou', Decimal('53.94')),
#  ('ACE GOLDFINGER', 3.0, 'Kumbakonam', Decimal('29.94')),
#  ('ACE GOLDFINGER', 3.0, 'Pereira', Decimal('53.94')),
#  ('ACE GOLDFINGER', 3.0, 'Touliu', Decimal('59.94')),
#  ('ACE GOLDFINGER', 4.0, 'Simferopol', Decimal('59.94')),
#  ('ACE GOLDFINGER', 4.0, 'Soshanguve', Decimal('29.94')),
#  ('ACE GOLDFINGER', 5.0, 'Balikesir', Decimal('29.94')),
#  ('ADAPTATION HOLES', 1.0, 'Shikarpur', Decimal('17.94')),
#  ('ADAPTATION HOLES', 2.0, 'Jelets', Decimal('17.94')),
#  ('ADAPTATION HOLES', 3.0, 'Cayenne', Decimal('17.94')),
#  ('ADAPTATION HOLES', 3.0, 'Coacalco de Berriozbal', Decimal('17.94')),
#  ('ADAPTATION HOLES', 3.0, 'Salinas', Decimal('17.94')),
#  ('ADAPTATION HOLES', 3.0, 'Santa Brbara dOeste', Decimal('17.94')),
#  ('ADAPTATION HOLES', 3.0, 'Sasebo', Decimal('29.94')),
#  ('ADAPTATION HOLES', 3.0, 'al-Qatif', Decimal('17.94')),
#  ('ADAPTATION HOLES', 4.0, 'Jodhpur', Decimal('17.94')),
#  ('ADAPTATION HOLES', 4.0, 'Miraj', Decimal('17.94')),
#  ('ADAPTATION HOLES', 4.0, 'Ogbomosho', Decimal('17.94')),
#  ('ADAPTATION HOLES', 4.0, 'Urawa', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 1.0, 'Hidalgo', Decimal('23.94')),
#  ('AFFAIR PREJUDICE', 1.0, 'Tuguegarao', Decimal('23.94')),
#  ('AFFAIR PREJUDICE', 2.0, 'Changzhou', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 2.0, 'Crdoba', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 3.0, 'Aparecida de Goinia', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 3.0, 'Atinsk', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 3.0, 'Avellaneda', Decimal('41.94')),
#  ('AFFAIR PREJUDICE', 3.0, 'Caracas', Decimal('41.94')),
#  ('AFFAIR PREJUDICE', 3.0, 'Laiwu', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 3.0, 'Rancagua', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Chiayi', Decimal('29.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Ciomas', Decimal('35.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Lublin', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Malm', Decimal('35.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Palghat (Palakkad)', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Qomsheh', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Saint-Denis', Decimal('23.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'San Felipe de Puerto Plata', Decimal('29.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Sirjan', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Sokoto', Decimal('29.94')),
#  ('AFFAIR PREJUDICE', 4.0, 'Tiefa', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 4.0, 's-Hertogenbosch', Decimal('17.94')),
#  ('AFFAIR PREJUDICE', 5.0, 'Caracas', Decimal('17.94')),
#  ('AFRICAN EGG', 1.0, 'Ivanovo', Decimal('23.94')),
#  ('AFRICAN EGG', 2.0, 'Okayama', Decimal('23.94')),
#  ('AFRICAN EGG', 2.0, 'Richmond Hill', Decimal('29.94')),
#  ('AFRICAN EGG', 3.0, 'Rampur', Decimal('23.94')),
#  ('AFRICAN EGG', 3.0, 'Smolensk', Decimal('29.94')),
#  ('AFRICAN EGG', 3.0, 'Tokat', Decimal('17.94')),
#  ('AFRICAN EGG', 4.0, 'Jedda', Decimal('29.94')),
#  ('AFRICAN EGG', 4.0, 'Jhansi', Decimal('17.94')),
#  ('AFRICAN EGG', 4.0, 'Kitwe', Decimal('29.94')),
#  ('AFRICAN EGG', 4.0, 'Salzburg', Decimal('35.94')),
#  ('AFRICAN EGG', 4.0, 'York', Decimal('29.94')),
#  ('AFRICAN EGG', 5.0, 'al-Manama', Decimal('17.94')),
#  ('AGENT TRUMAN', 1.0, 'Coatzacoalcos', Decimal('53.94')),
#  ('AGENT TRUMAN', 1.0, 'Izumisano', Decimal('35.94')),
#  ('AGENT TRUMAN', 2.0, 'Antofagasta', Decimal('23.94')),
#  ('AGENT TRUMAN', 2.0, 'Moscow', Decimal('53.94')),
#  ('AGENT TRUMAN', 2.0, 'Taizz', Decimal('41.94')),
#  ('AGENT TRUMAN', 3.0, 'Bhilwara', Decimal('53.94')),
#  ('AGENT TRUMAN', 3.0, 'Chisinau', Decimal('29.94')),
#  ('AGENT TRUMAN', 3.0, 'Citrus Heights', Decimal('41.94')),
#  ('AGENT TRUMAN', 3.0, 'Emeishan', Decimal('23.94')),
#  ('AGENT TRUMAN', 3.0, 'Luzinia', Decimal('23.94')),
#  ('AGENT TRUMAN', 3.0, 'Mogiljov', Decimal('41.94')),
#  ('AGENT TRUMAN', 3.0, 'Omdurman', Decimal('47.94')),
#  ('AGENT TRUMAN', 3.0, 'Sunnyvale', Decimal('29.94')),
#  ('AGENT TRUMAN', 3.0, 'Usak', Decimal('47.94')),
#  ('AGENT TRUMAN', 4.0, 'Aurora', Decimal('29.94')),
#  ('AGENT TRUMAN', 4.0, 'Huixquilucan', Decimal('29.94')),
#  ('AGENT TRUMAN', 4.0, 'Matsue', Decimal('35.94')),
#  ('AGENT TRUMAN', 4.0, 'Nantou', Decimal('17.94')),
#  ('AGENT TRUMAN', 4.0, 'Pontianak', Decimal('47.94')),
#  ('AGENT TRUMAN', 4.0, 'Quilmes', Decimal('17.94')),
#  ('AGENT TRUMAN', 4.0, 'Tafuna', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 2.0, 'Cavite', Decimal('47.94')),
#  ('AIRPLANE SIERRA', 2.0, 'Lubumbashi', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 3.0, 'Ibirit', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 3.0, 'Iwakuni', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 3.0, 'Johannesburg', Decimal('47.94')),
#  ('AIRPLANE SIERRA', 3.0, 'Jurez', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 3.0, 'Mahajanga', Decimal('35.94')),
#  ('AIRPLANE SIERRA', 3.0, 's-Hertogenbosch', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 4.0, 'Bhusawal', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 4.0, 'Kuwana', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 4.0, 'Salamanca', Decimal('35.94')),
#  ('AIRPLANE SIERRA', 4.0, 'Tsuyama', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 4.0, 'Yuncheng', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 4.0, 'Zalantun', Decimal('29.94')),
#  ('AIRPLANE SIERRA', 5.0, 'Sincelejo', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 1.0, 'Okinawa', Decimal('35.94')),
#  ('AIRPORT POLLOCK', 1.0, 'Pemalang', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 1.0, 'Taguig', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 2.0, 'Molodetno', Decimal('35.94')),
#  ('AIRPORT POLLOCK', 2.0, 'Portoviejo', Decimal('41.94')),
#  ('AIRPORT POLLOCK', 2.0, 'Vaduz', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 3.0, 'Augusta-Richmond County', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 3.0, 'Lilongwe', Decimal('47.94')),
#  ('AIRPORT POLLOCK', 3.0, 'Lublin', Decimal('41.94')),
#  ('AIRPORT POLLOCK', 3.0, 'Peoria', Decimal('35.94')),
#  ('AIRPORT POLLOCK', 3.0, 'Yangor', Decimal('35.94')),
#  ('AIRPORT POLLOCK', 4.0, 'Bamenda', Decimal('35.94')),
#  ('AIRPORT POLLOCK', 4.0, 'Dhaka', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 4.0, 'Erlangen', Decimal('35.94')),
#  ('AIRPORT POLLOCK', 4.0, 'Fukuyama', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 4.0, 'Palghat (Palakkad)', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 4.0, 'San Juan Bautista Tuxtepec', Decimal('29.94')),
#  ('AIRPORT POLLOCK', 4.0, 'Sanaa', Decimal('29.94')),
#  ('ALABAMA DEVIL', 3.0, 'Greensboro', Decimal('35.94')),
#  ('ALABAMA DEVIL', 3.0, 'Halifax', Decimal('47.94')),
#  ('ALABAMA DEVIL', 3.0, 'Otsu', Decimal('53.94')),
#  ('ALABAMA DEVIL', 3.0, 'Sunnyvale', Decimal('17.94')),
#  ('ALABAMA DEVIL', 3.0, 'Zaoyang', Decimal('35.94')),
#  ('ALABAMA DEVIL', 4.0, 'Arlington', Decimal('53.94')),
#  ('ALABAMA DEVIL', 4.0, 'Asuncin', Decimal('35.94')),
#  ('ALABAMA DEVIL', 4.0, 'Eskisehir', Decimal('17.94')),
#  ('ALABAMA DEVIL', 4.0, 'Kanazawa', Decimal('29.94')),
#  ('ALABAMA DEVIL', 4.0, 'Mit Ghamr', Decimal('17.94')),
#  ('ALABAMA DEVIL', 4.0, 'Probolinggo', Decimal('53.94')),
#  ('ALABAMA DEVIL', 5.0, 'Changhwa', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 2.0, 'Kaduna', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 2.0, 'Kisumu', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 2.0, 'La Plata', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 2.0, 'Olomouc', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Adoni', Decimal('41.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Balaiha', Decimal('41.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Coacalco de Berriozbal', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Deba Habe', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Dos Quebradas', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Halisahar', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Mwanza', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Ranchi', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Sogamoso', Decimal('47.94')),
#  ('ALADDIN CALENDAR', 3.0, 'Zalantun', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Effon-Alaiye', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Esfahan', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Gulbarga', Decimal('47.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Hodeida', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Monclova', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Okinawa', Decimal('29.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Stockport', Decimal('35.94')),
#  ('ALADDIN CALENDAR', 4.0, 'Valencia', Decimal('47.94')),
#  ('ALADDIN CALENDAR', 5.0, 'Izumisano', Decimal('47.94')),
#  ('ALAMO VIDEOTAPE', 1.0, 'Arecibo', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 1.0, 'Yuzhou', Decimal('23.94')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Meixian', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Rio Claro', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Tarlac', Decimal('11.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Baicheng', Decimal('11.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Bat Yam', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Ife', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Jinchang', Decimal('11.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Myingyan', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Papeete', Decimal('11.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Pudukkottai', Decimal('23.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Stara Zagora', Decimal('11.94')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Tanauan', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Berhampore (Baharampur)', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Duisburg', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Emmen', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Grand Prairie', Decimal('11.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Idfu', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Lapu-Lapu', Decimal('11.88')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Owo', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Pemalang', Decimal('5.94')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Zeleznogorsk', Decimal('5.94')),
#  ('ALASKA PHANTOM', 1.0, 'Nezahualcyotl', Decimal('5.94')),
#  ('ALASKA PHANTOM', 1.0, 'Zhezqazghan', Decimal('17.94')),
#  ('ALASKA PHANTOM', 2.0, 'Braslia', Decimal('17.94')),
#  ('ALASKA PHANTOM', 2.0, 'Maring', Decimal('5.94')),
#  ('ALASKA PHANTOM', 2.0, 'Sterling Heights', Decimal('11.94')),
#  ('ALASKA PHANTOM', 2.0, 'Touliu', Decimal('5.94')),
#  ('ALASKA PHANTOM', 2.0, 'al-Qadarif', Decimal('5.94')),
#  ('ALASKA PHANTOM', 3.0, 'Dhule (Dhulia)', Decimal('17.94')),
#  ('ALASKA PHANTOM', 3.0, 'Laohekou', Decimal('11.94')),
#  ('ALASKA PHANTOM', 3.0, 'Nabereznyje Telny', Decimal('5.94')),
#  ('ALASKA PHANTOM', 3.0, 'Nantou', Decimal('5.94')),
#  ('ALASKA PHANTOM', 3.0, 'Peoria', Decimal('23.94')),
#  ('ALASKA PHANTOM', 3.0, 'Saint Louis', Decimal('5.94')),
#  ('ALASKA PHANTOM', 3.0, 'Szkesfehrvr', Decimal('11.94')),
#  ('ALASKA PHANTOM', 3.0, 'Zhezqazghan', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Baicheng', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Bhilwara', Decimal('23.94')),
#  ('ALASKA PHANTOM', 4.0, 'Dhule (Dhulia)', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Lhokseumawe', Decimal('11.94')),
#  ('ALASKA PHANTOM', 4.0, 'Ljubertsy', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Mandi Bahauddin', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Niznekamsk', Decimal('17.94')),
#  ('ALASKA PHANTOM', 4.0, 'Omdurman', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Tiefa', Decimal('5.94')),
#  ('ALASKA PHANTOM', 4.0, 'Xiangtan', Decimal('11.94')),
#  ('ALASKA PHANTOM', 4.0, 'al-Hawiya', Decimal('5.94')),
#  ('ALI FOREVER', 3.0, 'Esfahan', Decimal('35.94')),
#  ('ALI FOREVER', 3.0, 'Lubumbashi', Decimal('29.94')),
#  ('ALI FOREVER', 3.0, 'Ourense (Orense)', Decimal('59.94')),
#  ('ALI FOREVER', 3.0, 'Sharja', Decimal('29.94')),
#  ('ALI FOREVER', 4.0, 'Cuauhtmoc', Decimal('47.94')),
#  ('ALI FOREVER', 4.0, 'Jakarta', Decimal('29.94')),
#  ('ALI FOREVER', 4.0, 'Maikop', Decimal('35.94')),
#  ('ALI FOREVER', 4.0, 'Vaduz', Decimal('29.94')),
#  ('ALI FOREVER', 5.0, 'Huixquilucan', Decimal('29.94')),
#  ('ALIEN CENTER', 1.0, 'Caracas', Decimal('17.94')),
#  ('ALIEN CENTER', 1.0, 'Escobar', Decimal('17.94')),
#  ('ALIEN CENTER', 2.0, 'Baiyin', Decimal('17.94')),
#  ('ALIEN CENTER', 2.0, 'Lengshuijiang', Decimal('17.94')),
#  ('ALIEN CENTER', 2.0, 'Rancagua', Decimal('29.94')),
#  ('ALIEN CENTER', 3.0, 'Bag', Decimal('17.94')),
#  ('ALIEN CENTER', 3.0, 'Hsichuh', Decimal('17.94')),
#  ('ALIEN CENTER', 3.0, 'Huejutla de Reyes', Decimal('17.94')),
#  ('ALIEN CENTER', 3.0, 'Kragujevac', Decimal('17.94')),
#  ('ALIEN CENTER', 3.0, 'Memphis', Decimal('41.94')),
#  ('ALIEN CENTER', 3.0, 'Nagareyama', Decimal('17.94')),
#  ('ALIEN CENTER', 3.0, 'San Felipe de Puerto Plata', Decimal('35.94')),
#  ('ALIEN CENTER', 3.0, 'Sanya', Decimal('29.94')),
#  ('ALIEN CENTER', 3.0, 'Songkhla', Decimal('17.94')),
#  ('ALIEN CENTER', 4.0, 'Cuman', Decimal('17.94')),
#  ('ALIEN CENTER', 4.0, 'El Fuerte', Decimal('29.94')),
#  ('ALIEN CENTER', 4.0, 'Emeishan', Decimal('41.94')),
#  ('ALIEN CENTER', 4.0, 'Juazeiro do Norte', Decimal('23.94')),
#  ('ALIEN CENTER', 4.0, 'Richmond Hill', Decimal('17.94')),
#  ('ALIEN CENTER', 4.0, 'Shahr-e Kord', Decimal('17.94')),
#  ('ALIEN CENTER', 4.0, 'Xiangfan', Decimal('41.94')),
#  ('ALIEN CENTER', 4.0, 'Zhezqazghan', Decimal('35.94')),
#  ('ALLEY EVOLUTION', 1.0, 'Najafabad', Decimal('35.94')),
#  ('ALLEY EVOLUTION', 2.0, 'Lancaster', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 2.0, 'Mexicali', Decimal('41.94')),
#  ('ALLEY EVOLUTION', 3.0, 'Aden', Decimal('29.94')),
#  ('ALLEY EVOLUTION', 3.0, 'Jos Azueta', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 3.0, 'Kalisz', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 3.0, 'Ponce', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 3.0, 'Shahr-e Kord', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 3.0, 'Tuguegarao', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 4.0, 'Esfahan', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 4.0, 'NDjamna', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 4.0, 'Shikarpur', Decimal('17.94')),
#  ('ALLEY EVOLUTION', 4.0, 'Tonghae', Decimal('29.94')),
#  ('ALLEY EVOLUTION', 4.0, 'Tsaotun', Decimal('17.94')),
#  ('ALONE TRIP', 1.0, 'Arak', Decimal('5.94')),
#  ('ALONE TRIP', 2.0, 'Almirante Brown', Decimal('5.94')),
#  ('ALONE TRIP', 2.0, 'Tuguegarao', Decimal('23.94')),
#  ('ALONE TRIP', 3.0, 'Kamjanets-Podilskyi', Decimal('23.94')),
#  ('ALONE TRIP', 3.0, 'Lungtan', Decimal('17.94')),
#  ('ALONE TRIP', 3.0, 'NDjamna', Decimal('5.94')),
#  ('ALONE TRIP', 3.0, 'Sincelejo', Decimal('17.94')),
#  ('ALONE TRIP', 3.0, 'Sousse', Decimal('29.94')),
#  ('ALONE TRIP', 3.0, 'Sterling Heights', Decimal('29.94')),
#  ('ALONE TRIP', 3.0, 'Tarsus', Decimal('17.94')),
#  ('ALONE TRIP', 3.0, 'Vinh', Decimal('11.94')),
#  ('ALONE TRIP', 4.0, 'Arecibo', Decimal('11.94')),
#  ('ALONE TRIP', 4.0, 'Cabuyao', Decimal('11.94')),
#  ('ALONE TRIP', 4.0, 'Hami', Decimal('41.94')),
#  ('ALONE TRIP', 4.0, 'Huixquilucan', Decimal('29.94')),
#  ('ALONE TRIP', 4.0, 'Mwanza', Decimal('41.94')),
#  ('ALONE TRIP', 4.0, 'Syktyvkar', Decimal('41.94')),
#  ('ALONE TRIP', 5.0, 'Tanza', Decimal('5.94')),
#  ('ALTER VICTORY', 1.0, 'Ezhou', Decimal('5.94')),
#  ('ALTER VICTORY', 1.0, 'Vinh', Decimal('5.94')),
#  ('ALTER VICTORY', 2.0, 'Charlotte Amalie', Decimal('5.94')),
#  ('ALTER VICTORY', 2.0, 'Cianjur', Decimal('5.94')),
#  ('ALTER VICTORY', 2.0, 'Purnea (Purnia)', Decimal('5.94')),
#  ('ALTER VICTORY', 3.0, 'Alessandria', Decimal('5.94')),
#  ('ALTER VICTORY', 3.0, 'Bijapur', Decimal('5.94')),
#  ('ALTER VICTORY', 3.0, 'Kamyin', Decimal('5.94')),
#  ('ALTER VICTORY', 3.0, 'Korolev', Decimal('5.94')),
#  ('ALTER VICTORY', 3.0, 'Meixian', Decimal('5.94')),
#  ('ALTER VICTORY', 3.0, 'Tongliao', Decimal('11.94')),
#  ('ALTER VICTORY', 4.0, 'Addis Abeba', Decimal('11.94')),
#  ('ALTER VICTORY', 4.0, 'Avellaneda', Decimal('5.94')),
#  ('ALTER VICTORY', 4.0, 'Bandar Seri Begawan', Decimal('5.94')),
#  ('ALTER VICTORY', 4.0, 'Kitwe', Decimal('23.94')),
#  ('ALTER VICTORY', 4.0, 'Nantou', Decimal('5.94')),
#  ('ALTER VICTORY', 4.0, 'Shaoguan', Decimal('23.94')),
#  ('ALTER VICTORY', 4.0, 'Shimonoseki', Decimal('5.94')),
#  ('ALTER VICTORY', 4.0, 'Sirjan', Decimal('23.94')),
#  ('ALTER VICTORY', 4.0, 'Tiefa', Decimal('5.94')),
#  ('ALTER VICTORY', 4.0, 'Urawa', Decimal('5.94')),
#  ('ALTER VICTORY', 5.0, 'Boksburg', Decimal('5.94')),
#  ('AMADEUS HOLY', 1.0, 'La Plata', Decimal('5.94')),
#  ('AMADEUS HOLY', 2.0, 'Denizli', Decimal('5.94')),
#  ('AMADEUS HOLY', 2.0, 'Jakarta', Decimal('5.94')),
#  ('AMADEUS HOLY', 2.0, 'Kurashiki', Decimal('5.94')),
#  ('AMADEUS HOLY', 2.0, 'Myingyan', Decimal('5.94')),
#  ('AMADEUS HOLY', 3.0, 'Araatuba', Decimal('5.94')),
#  ('AMADEUS HOLY', 3.0, 'Citt del Vaticano', Decimal('11.94')),
#  ('AMADEUS HOLY', 3.0, 'Joliet', Decimal('23.94')),
#  ('AMADEUS HOLY', 3.0, 'Laredo', Decimal('5.94')),
#  ('AMADEUS HOLY', 3.0, 'Matamoros', Decimal('5.94')),
#  ('AMADEUS HOLY', 3.0, 'Shubra al-Khayma', Decimal('23.94')),
#  ('AMADEUS HOLY', 3.0, 'Vila Velha', Decimal('5.94')),
#  ('AMADEUS HOLY', 4.0, 'Arak', Decimal('5.94')),
#  ('AMADEUS HOLY', 4.0, 'Bilbays', Decimal('11.94')),
#  ('AMADEUS HOLY', 4.0, 'Hohhot', Decimal('11.94')),
#  ('AMADEUS HOLY', 4.0, 'Jining', Decimal('5.94')),
#  ('AMADEUS HOLY', 4.0, 'Nabereznyje Telny', Decimal('5.94')),
#  ('AMADEUS HOLY', 4.0, 'Pjatigorsk', Decimal('5.94')),
#  ('AMADEUS HOLY', 4.0, 'Poos de Caldas', Decimal('23.94')),
#  ('AMADEUS HOLY', 4.0, 'Warren', Decimal('11.94')),
#  ('AMADEUS HOLY', 5.0, 'London', Decimal('5.94')),
#  ('AMELIE HELLFIGHTERS', 2.0, 'Acua', Decimal('29.94')),
#  ('AMELIE HELLFIGHTERS', 2.0, 'Ipoh', Decimal('35.94')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Anpolis', Decimal('29.94')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Sterling Heights', Decimal('29.94')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Tonghae', Decimal('53.94')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Botshabelo', Decimal('35.94')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Funafuti', Decimal('59.94')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Madiun', Decimal('29.94')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Meixian', Decimal('41.94')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'So Bernardo do Campo', Decimal('59.94')),
#  ('AMERICAN CIRCUS', 1.0, 'Callao', Decimal('65.94')),
#  ('AMERICAN CIRCUS', 1.0, 'Juazeiro do Norte', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 2.0, 'Dos Quebradas', Decimal('59.94')),
#  ('AMERICAN CIRCUS', 2.0, 'El Fuerte', Decimal('41.94')),
#  ('AMERICAN CIRCUS', 2.0, 'Oulu', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Bayugan', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Bergamo', Decimal('35.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Bijapur', Decimal('65.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Changhwa', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Imus', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Konotop', Decimal('65.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Nagaon', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 3.0, 'Oulu', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Benguela', Decimal('59.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Bydgoszcz', Decimal('29.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Cabuyao', Decimal('53.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Halle/Saale', Decimal('53.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Juazeiro do Norte', Decimal('59.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Nador', Decimal('53.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Saint-Denis', Decimal('65.94')),
#  ('AMERICAN CIRCUS', 4.0, 'Tiefa', Decimal('53.94')),
#  ('AMERICAN CIRCUS', 5.0, 'Lipetsk', Decimal('29.94')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Akron', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Mysore', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Shimonoseki', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Elista', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Garland', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Jastrzebie-Zdrj', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Kolpino', Decimal('23.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Miyakonojo', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Vijayawada', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Zanzibar', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 3.0, 's-Hertogenbosch', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Apeldoorn', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Arecibo', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Avellaneda', Decimal('29.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Cavite', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Effon-Alaiye', Decimal('35.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Nantou', Decimal('23.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Sasebo', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Usak', Decimal('17.94')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Xinxiang', Decimal('23.94')),
#  ('AMISTAD MIDSUMMER', 5.0, 'Imus', Decimal('17.94')),
#  ('ANACONDA CONFESSIONS', 1.0, 'Fengshan', Decimal('5.94')),
#  ('ANACONDA CONFESSIONS', 1.0, 'Tarsus', Decimal('11.94')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Athenai', Decimal('41.94')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Dallas', Decimal('5.94')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Kermanshah', Decimal('11.94')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Nanyang', Decimal('23.94')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Otsu', Decimal('35.94')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Botshabelo', Decimal('5.94')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Haldia', Decimal('5.94')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Roanoke', Decimal('35.94')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Shanwei', Decimal('17.94')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Uttarpara-Kotrung', Decimal('5.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Batman', Decimal('35.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Caracas', Decimal('11.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Charlotte Amalie', Decimal('5.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Jelets', Decimal('11.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Molodetno', Decimal('23.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Sambhal', Decimal('17.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'San Juan Bautista Tuxtepec', Decimal('17.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Tanza', Decimal('23.94')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Vitria de Santo Anto', Decimal('5.94')),
#  ('ANALYZE HOOSIERS', 2.0, 'Saint Louis', Decimal('29.94')),
#  ('ANALYZE HOOSIERS', 2.0, 'Xintai', Decimal('17.94')),
#  ('ANALYZE HOOSIERS', 2.0, 'Yuncheng', Decimal('17.94')),
#  ('ANALYZE HOOSIERS', 3.0, 'Bijapur', Decimal('23.94')),
#  ('ANALYZE HOOSIERS', 3.0, 'Ciudad del Este', Decimal('17.94')),
#  ('ANALYZE HOOSIERS', 3.0, 'Joliet', Decimal('17.94')),
#  ('ANALYZE HOOSIERS', 3.0, 'Tartu', Decimal('29.94')),
#  ('ANALYZE HOOSIERS', 4.0, 'Ambattur', Decimal('29.94')),
#  ('ANALYZE HOOSIERS', 4.0, 'Celaya', Decimal('23.94')),
#  ('ANALYZE HOOSIERS', 4.0, 'Kurashiki', Decimal('35.94')),
#  ('ANALYZE HOOSIERS', 4.0, 'Kuwana', Decimal('17.94')),
#  ('ANALYZE HOOSIERS', 4.0, 'Usak', Decimal('17.94')),
#  ('ANALYZE HOOSIERS', 4.0, 'Valparai', Decimal('23.94')),
#  ('ANALYZE HOOSIERS', 5.0, 'Citrus Heights', Decimal('29.94')),
#  ('ANGELS LIFE', 1.0, 'Adana', Decimal('41.94')),
#  ('ANGELS LIFE', 1.0, 'Salala', Decimal('53.94')),
#  ('ANGELS LIFE', 2.0, 'Arecibo', Decimal('23.94')),
#  ('ANGELS LIFE', 2.0, 'Kermanshah', Decimal('23.94')),
#  ('ANGELS LIFE', 2.0, 'Urawa', Decimal('17.94')),
#  ('ANGELS LIFE', 3.0, 'Fukuyama', Decimal('23.94')),
#  ('ANGELS LIFE', 3.0, 'Greensboro', Decimal('17.94')),
#  ('ANGELS LIFE', 3.0, 'Kakamigahara', Decimal('17.94')),
#  ('ANGELS LIFE', 3.0, 'Nagareyama', Decimal('35.94')),
#  ('ANGELS LIFE', 3.0, 'Salamanca', Decimal('53.94')),
#  ('ANGELS LIFE', 3.0, 'San Juan Bautista Tuxtepec', Decimal('41.94')),
#  ('ANGELS LIFE', 3.0, 'Teboksary', Decimal('41.94')),
#  ('ANGELS LIFE', 3.0, 'Wroclaw', Decimal('47.94')),
#  ('ANGELS LIFE', 4.0, 'Ambattur', Decimal('17.94')),
#  ('ANGELS LIFE', 4.0, 'Augusta-Richmond County', Decimal('17.94')),
#  ('ANGELS LIFE', 4.0, 'Carmen', Decimal('35.94')),
#  ('ANGELS LIFE', 4.0, 'Kakamigahara', Decimal('23.94')),
#  ('ANGELS LIFE', 4.0, 'Korolev', Decimal('47.94')),
#  ('ANGELS LIFE', 4.0, 'Olomouc', Decimal('17.94')),
#  ('ANGELS LIFE', 4.0, 'Rampur', Decimal('53.94')),
#  ('ANGELS LIFE', 4.0, 'Sharja', Decimal('41.94')),
#  ('ANGELS LIFE', 4.0, 'York', Decimal('17.94')),
#  ('ANNIE IDENTITY', 1.0, 'Jedda', Decimal('23.94')),
#  ('ANNIE IDENTITY', 1.0, 'Maring', Decimal('23.94')),
#  ('ANNIE IDENTITY', 1.0, 'Tel Aviv-Jaffa', Decimal('5.94')),
#  ('ANNIE IDENTITY', 2.0, 'Battambang', Decimal('17.94')),
#  ('ANNIE IDENTITY', 2.0, 'Ede', Decimal('35.94')),
#  ('ANNIE IDENTITY', 2.0, 'Goinia', Decimal('5.94')),
#  ('ANNIE IDENTITY', 2.0, 'Tama', Decimal('5.94')),
#  ('ANNIE IDENTITY', 3.0, 'Ashqelon', Decimal('29.94')),
#  ('ANNIE IDENTITY', 3.0, 'Czestochowa', Decimal('29.94')),
#  ('ANNIE IDENTITY', 3.0, 'Myingyan', Decimal('11.94')),
#  ('ANNIE IDENTITY', 3.0, 'Pangkal Pinang', Decimal('5.94')),
#  ('ANNIE IDENTITY', 3.0, 'Santa F', Decimal('17.94')),
#  ('ANNIE IDENTITY', 3.0, 'Shaoguan', Decimal('41.94')),
#  ('ANNIE IDENTITY', 3.0, 'Yuncheng', Decimal('5.94')),
#  ('ANNIE IDENTITY', 4.0, 'Cabuyao', Decimal('5.94')),
#  ('ANNIE IDENTITY', 4.0, 'Luzinia', Decimal('5.94')),
#  ('ANNIE IDENTITY', 4.0, 'Oyo', Decimal('5.94')),
#  ('ANNIE IDENTITY', 4.0, 'Szkesfehrvr', Decimal('5.94')),
#  ('ANNIE IDENTITY', 4.0, 'Vilnius', Decimal('11.94')),
#  ('ANNIE IDENTITY', 4.0, 'Zanzibar', Decimal('5.94')),
#  ('ANNIE IDENTITY', 4.0, 'Zaria', Decimal('35.94')),
#  ('ANNIE IDENTITY', 4.0, 'Zhoushan', Decimal('17.94')),
#  ('ANONYMOUS HUMAN', 2.0, 'Uruapan', Decimal('11.94')),
#  ('ANONYMOUS HUMAN', 2.0, 'Varanasi (Benares)', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 3.0, 'Basel', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 3.0, 'Ezhou', Decimal('17.94')),
#  ('ANONYMOUS HUMAN', 3.0, 'Kowloon and New Kowloon', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 3.0, 'La Romana', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 3.0, 'San Bernardino', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 3.0, 'Zhezqazghan', Decimal('11.94')),
#  ('ANONYMOUS HUMAN', 4.0, 'Dhaka', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 4.0, 'Iwakuni', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 4.0, 'Kamakura', Decimal('11.94')),
#  ('ANONYMOUS HUMAN', 4.0, 'Liepaja', Decimal('5.94')),
#  ('ANONYMOUS HUMAN', 4.0, 'Richmond Hill', Decimal('5.94')),
#  ('ANTHEM LUKE', 1.0, 'Lengshuijiang', Decimal('41.94')),
#  ('ANTHEM LUKE', 1.0, 'Pyongyang', Decimal('29.94')),
#  ('ANTHEM LUKE', 1.0, 'Uluberia', Decimal('29.94')),
#  ('ANTHEM LUKE', 2.0, 'Ashgabat', Decimal('29.94')),
#  ('ANTHEM LUKE', 2.0, 'Cuauhtmoc', Decimal('29.94')),
#  ('ANTHEM LUKE', 2.0, 'San Felipe del Progreso', Decimal('29.94')),
#  ('ANTHEM LUKE', 3.0, 'Acua', Decimal('29.94')),
#  ('ANTHEM LUKE', 3.0, 'Fukuyama', Decimal('29.94')),
#  ('ANTHEM LUKE', 3.0, 'Ozamis', Decimal('29.94')),
#  ('ANTHEM LUKE', 4.0, 'Boa Vista', Decimal('53.94')),
#  ('ANTHEM LUKE', 4.0, 'Changzhou', Decimal('29.94')),
#  ('ANTHEM LUKE', 4.0, 'Coacalco de Berriozbal', Decimal('29.94')),
#  ('ANTHEM LUKE', 4.0, 'Kuwana', Decimal('35.94')),
#  ('ANTHEM LUKE', 4.0, 'Lhokseumawe', Decimal('53.94')),
#  ('ANTHEM LUKE', 5.0, 'Kirovo-Tepetsk', Decimal('29.94')),
#  ('ANTITRUST TOMATOES', 1.0, 'Erlangen', Decimal('17.94')),
#  ('ANTITRUST TOMATOES', 1.0, 'Novoterkassk', Decimal('17.94')),
#  ('ANTITRUST TOMATOES', 2.0, 'Lapu-Lapu', Decimal('41.94')),
#  ('ANTITRUST TOMATOES', 2.0, 'Sharja', Decimal('23.94')),
#  ('ANTITRUST TOMATOES', 3.0, 'Malm', Decimal('17.94')),
#  ('ANTITRUST TOMATOES', 3.0, 'Pereira', Decimal('17.94')),
#  ('ANTITRUST TOMATOES', 4.0, 'Bhimavaram', Decimal('23.94')),
#  ('ANTITRUST TOMATOES', 4.0, 'Fuyu', Decimal('29.94')),
#  ('ANTITRUST TOMATOES', 4.0, 'Vijayawada', Decimal('17.94')),
#  ('ANTITRUST TOMATOES', 4.0, 'Ziguinchor', Decimal('17.94')),
#  ('ANYTHING SAVANNAH', 1.0, 'Halle/Saale', Decimal('17.94')),
#  ('ANYTHING SAVANNAH', 2.0, 'Araatuba', Decimal('29.94')),
#  ('ANYTHING SAVANNAH', 2.0, 'Mexicali', Decimal('41.94')),
#  ('ANYTHING SAVANNAH', 3.0, 'Cam Ranh', Decimal('23.94')),
#  ('ANYTHING SAVANNAH', 3.0, 'El Monte', Decimal('35.94')),
#  ('ANYTHING SAVANNAH', 3.0, 'Gandhinagar', Decimal('17.94')),
#  ('ANYTHING SAVANNAH', 3.0, 'Yangor', Decimal('47.94')),
#  ('ANYTHING SAVANNAH', 4.0, 'Banjul', Decimal('47.94')),
#  ('ANYTHING SAVANNAH', 4.0, 'Zaoyang', Decimal('17.94')),
#  ('APACHE DIVINE', 1.0, 'Cavite', Decimal('29.94')),
#  ('APACHE DIVINE', 1.0, 'Mukateve', Decimal('47.94')),
#  ('APACHE DIVINE', 1.0, 'So Leopoldo', Decimal('29.94')),
#  ('APACHE DIVINE', 2.0, 'Bamenda', Decimal('29.94')),
#  ('APACHE DIVINE', 2.0, 'Cam Ranh', Decimal('29.94')),
#  ('APACHE DIVINE', 2.0, 'Iwaki', Decimal('29.94')),
#  ('APACHE DIVINE', 2.0, 'Taizz', Decimal('29.94')),
#  ('APACHE DIVINE', 3.0, 'Balikesir', Decimal('41.94')),
#  ('APACHE DIVINE', 3.0, 'Boksburg', Decimal('47.94')),
#  ('APACHE DIVINE', 3.0, 'El Fuerte', Decimal('41.94')),
#  ('APACHE DIVINE', 3.0, 'Guadalajara', Decimal('29.94')),
#  ('APACHE DIVINE', 3.0, 'Kanazawa', Decimal('29.94')),
#  ('APACHE DIVINE', 3.0, 'Maikop', Decimal('35.94')),
#  ('APACHE DIVINE', 3.0, 'Moscow', Decimal('35.94')),
#  ('APACHE DIVINE', 3.0, 'Okinawa', Decimal('53.94')),
#  ('APACHE DIVINE', 3.0, 'Sorocaba', Decimal('29.94')),
#  ('APACHE DIVINE', 3.0, 'Urawa', Decimal('29.94')),
#  ('APACHE DIVINE', 3.0, 'Zanzibar', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Bandar Seri Begawan', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Carmen', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Greensboro', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Jaffna', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Kimberley', Decimal('35.94')),
#  ('APACHE DIVINE', 4.0, 'Malm', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Mit Ghamr', Decimal('41.94')),
#  ('APACHE DIVINE', 4.0, 'Oshawa', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Pereira', Decimal('35.94')),
#  ('APACHE DIVINE', 4.0, 'Robamba', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'Taguig', Decimal('35.94')),
#  ('APACHE DIVINE', 4.0, 'Tiefa', Decimal('29.94')),
#  ('APACHE DIVINE', 4.0, 'York', Decimal('47.94')),
#  ('APOCALYPSE FLAMINGOS', 2.0, 'Kalisz', Decimal('35.94')),
#  ('APOCALYPSE FLAMINGOS', 3.0, 'Chandrapur', Decimal('29.94')),
#  ('APOCALYPSE FLAMINGOS', 3.0, 'Ikerre', Decimal('29.94')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Belm', Decimal('29.94')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Blumenau', Decimal('29.94')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Ruse', Decimal('29.94')),
#  ('ARABIA DOGMA', 1.0, 'Tartu', Decimal('5.94')),
#  ('ARABIA DOGMA', 2.0, 'Qalyub', Decimal('5.94')),
#  ('ARABIA DOGMA', 2.0, 'Toulouse', Decimal('5.94')),
#  ('ARABIA DOGMA', 3.0, 'Amroha', Decimal('5.94')),
#  ('ARABIA DOGMA', 3.0, 'La Plata', Decimal('23.94')),
#  ('ARABIA DOGMA', 3.0, 'London', Decimal('23.94')),
#  ('ARABIA DOGMA', 3.0, 'Lubumbashi', Decimal('5.94')),
#  ('ARABIA DOGMA', 3.0, 'Monclova', Decimal('23.94')),
#  ('ARABIA DOGMA', 3.0, 'Tokat', Decimal('11.94')),
#  ('ARABIA DOGMA', 4.0, 'Changzhou', Decimal('5.94')),
#  ('ARABIA DOGMA', 4.0, 'Lapu-Lapu', Decimal('5.94')),
#  ('ARABIA DOGMA', 4.0, 'Tuguegarao', Decimal('5.94')),
#  ('ARABIA DOGMA', 4.0, 'Usak', Decimal('5.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Arlington', Decimal('29.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Bhusawal', Decimal('17.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Mwene-Ditu', Decimal('35.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Tonghae', Decimal('29.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Czestochowa', Decimal('41.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Higashiosaka', Decimal('23.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Kimberley', Decimal('17.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Matsue', Decimal('23.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Ondo', Decimal('41.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Parbhani', Decimal('23.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Zalantun', Decimal('35.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Chapra', Decimal('41.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Dadu', Decimal('17.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Fuyu', Decimal('23.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Gaziantep', Decimal('47.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Goinia', Decimal('17.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Jamalpur', Decimal('29.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Kamakura', Decimal('17.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Myingyan', Decimal('23.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Rio Claro', Decimal('23.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Roanoke', Decimal('17.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Usak', Decimal('35.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Vicente Lpez', Decimal('47.94')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Zhezqazghan', Decimal('17.94')),
#  ('ARIZONA BANG', 2.0, 'Jalib al-Shuyukh', Decimal('35.94')),
#  ('ARIZONA BANG', 2.0, 'Szkesfehrvr', Decimal('17.94')),
#  ('ARIZONA BANG', 2.0, 'guas Lindas de Gois', Decimal('17.94')),
#  ('ARIZONA BANG', 3.0, 'Hamilton', Decimal('17.94')),
#  ('ARIZONA BANG', 3.0, 'Kowloon and New Kowloon', Decimal('47.94')),
#  ('ARIZONA BANG', 3.0, 'Molodetno', Decimal('29.94')),
#  ('ARIZONA BANG', 3.0, 'Nantou', Decimal('17.94')),
#  ('ARIZONA BANG', 3.0, 'Palghat (Palakkad)', Decimal('47.94')),
#  ('ARIZONA BANG', 3.0, 'Pontianak', Decimal('29.94')),
#  ('ARIZONA BANG', 3.0, 'Probolinggo', Decimal('17.94')),
#  ('ARIZONA BANG', 3.0, 'Rajkot', Decimal('47.94')),
#  ('ARIZONA BANG', 3.0, 'Salala', Decimal('17.94')),
#  ('ARIZONA BANG', 3.0, 'Shikarpur', Decimal('29.94')),
#  ('ARIZONA BANG', 3.0, 'Springs', Decimal('35.94')),
#  ('ARIZONA BANG', 3.0, 'Vijayawada', Decimal('41.94')),
#  ('ARIZONA BANG', 4.0, 'Battambang', Decimal('23.94')),
#  ('ARIZONA BANG', 4.0, 'Davao', Decimal('29.94')),
#  ('ARIZONA BANG', 4.0, 'Lancaster', Decimal('35.94')),
#  ('ARIZONA BANG', 4.0, 'Liepaja', Decimal('47.94')),
#  ('ARIZONA BANG', 4.0, 'Osmaniye', Decimal('17.94')),
#  ('ARIZONA BANG', 4.0, 'Saint-Denis', Decimal('17.94')),
#  ('ARMAGEDDON LOST', 1.0, 'Dallas', Decimal('23.94')),
#  ('ARMAGEDDON LOST', 2.0, 'Surakarta', Decimal('29.94')),
#  ('ARMAGEDDON LOST', 2.0, 'Tallahassee', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 3.0, 'Bhavnagar', Decimal('23.94')),
#  ('ARMAGEDDON LOST', 3.0, 'Dzerzinsk', Decimal('35.94')),
#  ('ARMAGEDDON LOST', 3.0, 'Hanoi', Decimal('11.94')),
#  ('ARMAGEDDON LOST', 3.0, 'NDjamna', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 3.0, 'Nanyang', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 3.0, 'Rio Claro', Decimal('11.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Bradford', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Cheju', Decimal('11.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Cianjur', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Hiroshima', Decimal('17.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Luzinia', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Nakhon Sawan', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Rae Bareli', Decimal('23.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Saint-Denis', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Szkesfehrvr', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 4.0, 'Uijongbu', Decimal('5.94')),
#  ('ARMAGEDDON LOST', 5.0, 'Ambattur', Decimal('17.94')),
#  ('ARMAGEDDON LOST', 5.0, 'Trshavn', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 1.0, 'Lublin', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 1.0, 'Sunnyvale', Decimal('23.94')),
#  ('ARMY FLINTSTONES', 2.0, 'Kamarhati', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 2.0, 'Rae Bareli', Decimal('17.94')),
#  ('ARMY FLINTSTONES', 2.0, 'Sterling Heights', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 3.0, 'Boa Vista', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 3.0, 'Lengshuijiang', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 3.0, 'Po', Decimal('23.94')),
#  ('ARMY FLINTSTONES', 3.0, 'Yamuna Nagar', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 3.0, 'Yuzhou', Decimal('29.94')),
#  ('ARMY FLINTSTONES', 4.0, 'Aden', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 4.0, 'Cavite', Decimal('5.94')),
#  ('ARMY FLINTSTONES', 4.0, 'Jodhpur', Decimal('17.94')),
#  ('ARMY FLINTSTONES', 4.0, 'Kurashiki', Decimal('23.94')),
#  ('ARMY FLINTSTONES', 4.0, 'Pune', Decimal('23.94')),
#  ('ARMY FLINTSTONES', 4.0, 'Skikda', Decimal('41.94')),
#  ('ARTIST COLDBLOODED', 1.0, 'Ogbomosho', Decimal('41.94')),
#  ('ARTIST COLDBLOODED', 1.0, 'Rajkot', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 2.0, 'Hamilton', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 2.0, 'Myingyan', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 2.0, 'Valencia', Decimal('23.94')),
#  ('ARTIST COLDBLOODED', 3.0, 'Funafuti', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 3.0, 'Jastrzebie-Zdrj', Decimal('23.94')),
#  ('ARTIST COLDBLOODED', 3.0, 'Mosul', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 3.0, 'Tafuna', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Ashdod', Decimal('41.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Bijapur', Decimal('35.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Duisburg', Decimal('17.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Juazeiro do Norte', Decimal('41.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Lubumbashi', Decimal('35.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Nha Trang', Decimal('29.94')),
#  ('ARTIST COLDBLOODED', 4.0, 'Zaria', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 1.0, 'Sivas', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 1.0, 's-Hertogenbosch', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 2.0, 'Balurghat', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 2.0, 'Beni-Mellal', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 2.0, 'Fuzhou', Decimal('35.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Brockton', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Caracas', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Emmen', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Jodhpur', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Sambhal', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Sogamoso', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Tabriz', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 3.0, 'Tanauan', Decimal('35.94')),
#  ('ATLANTIS CAUSE', 3.0, 'al-Manama', Decimal('35.94')),
#  ('ATLANTIS CAUSE', 3.0, 'guas Lindas de Gois', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Abu Dhabi', Decimal('23.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Ashgabat', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Deba Habe', Decimal('35.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Duisburg', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Jining', Decimal('23.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Klerksdorp', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Pontianak', Decimal('17.94')),
#  ('ATLANTIS CAUSE', 4.0, 'Pudukkottai', Decimal('23.94')),
#  ('ATLANTIS CAUSE', 5.0, 'Xiangfan', Decimal('23.94')),
#  ('ATTACKS HATE', 2.0, 'Sasebo', Decimal('29.94')),
#  ('ATTACKS HATE', 2.0, 'Yangor', Decimal('47.94')),
#  ('ATTACKS HATE', 3.0, 'Aden', Decimal('47.94')),
#  ('ATTACKS HATE', 3.0, 'Antofagasta', Decimal('53.94')),
#  ('ATTACKS HATE', 3.0, 'Banjul', Decimal('53.94')),
#  ('ATTACKS HATE', 3.0, 'Ife', Decimal('29.94')),
#  ('ATTACKS HATE', 3.0, 'Munger (Monghyr)', Decimal('29.94')),
#  ('ATTACKS HATE', 3.0, 'Owo', Decimal('35.94')),
#  ('ATTACKS HATE', 4.0, 'Ashdod', Decimal('35.94')),
#  ('ATTACKS HATE', 4.0, 'Bern', Decimal('29.94')),
#  ('ATTACKS HATE', 4.0, 'Carmen', Decimal('29.94')),
#  ('ATTACKS HATE', 4.0, 'Ipoh', Decimal('29.94')),
#  ('ATTACKS HATE', 4.0, 'Matsue', Decimal('35.94')),
#  ('ATTACKS HATE', 4.0, 'Sumy', Decimal('53.94')),
#  ('ATTACKS HATE', 4.0, 'Tangail', Decimal('35.94')),
#  ('ATTACKS HATE', 4.0, 'Ueda', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 1.0, 'Sincelejo', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 2.0, 'Ezhou', Decimal('47.94')),
#  ('ATTRACTION NEWTON', 2.0, 'Lengshuijiang', Decimal('41.94')),
#  ('ATTRACTION NEWTON', 2.0, 'Nagaon', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 2.0, 'Portoviejo', Decimal('53.94')),
#  ('ATTRACTION NEWTON', 2.0, 'Tete', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Changzhou', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Jakarta', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Kimberley', Decimal('53.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Mit Ghamr', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Monywa', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Mukateve', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Patiala', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Salzburg', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Southend-on-Sea', Decimal('41.94')),
#  ('ATTRACTION NEWTON', 3.0, 'Zapopan', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Akishima', Decimal('47.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Amroha', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Batna', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Fontana', Decimal('35.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Maikop', Decimal('29.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Maracabo', Decimal('53.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Tongliao', Decimal('35.94')),
#  ('ATTRACTION NEWTON', 4.0, 'Zeleznogorsk', Decimal('47.94')),
#  ('AUTUMN CROW', 1.0, 'Ashgabat', Decimal('59.94')),
#  ('AUTUMN CROW', 2.0, 'Iwakuni', Decimal('41.94')),
#  ('AUTUMN CROW', 2.0, 'Stockport', Decimal('65.94')),
#  ('AUTUMN CROW', 3.0, 'Basel', Decimal('59.94')),
#  ('AUTUMN CROW', 3.0, 'Blumenau', Decimal('59.94')),
#  ('AUTUMN CROW', 3.0, 'Touliu', Decimal('35.94')),
#  ('AUTUMN CROW', 4.0, 'Aparecida de Goinia', Decimal('29.94')),
#  ('AUTUMN CROW', 4.0, 'Dallas', Decimal('29.94')),
#  ('AUTUMN CROW', 4.0, 'Fontana', Decimal('59.94')),
#  ('AUTUMN CROW', 4.0, 'Sincelejo', Decimal('29.94')),
#  ('AUTUMN CROW', 4.0, 'Tanshui', Decimal('35.94')),
#  ('BABY HALL', 2.0, 'Memphis', Decimal('35.94')),
#  ('BABY HALL', 2.0, 'Novoterkassk', Decimal('29.94')),
#  ('BABY HALL', 3.0, 'Lilongwe', Decimal('29.94')),
#  ('BABY HALL', 3.0, 'Osmaniye', Decimal('29.94')),
#  ('BABY HALL', 3.0, 'San Juan Bautista Tuxtepec', Decimal('29.94')),
#  ('BABY HALL', 4.0, 'Ilorin', Decimal('41.94')),
#  ('BABY HALL', 4.0, 'Lincoln', Decimal('29.94')),
#  ('BABY HALL', 4.0, 'Surakarta', Decimal('47.94')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Kaliningrad', Decimal('35.94')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Kamyin', Decimal('29.94')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Maring', Decimal('41.94')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Bellevue', Decimal('59.94')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Cuauhtmoc', Decimal('59.94')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Jedda', Decimal('29.94')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Springs', Decimal('29.94')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Blumenau', Decimal('65.94')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Etawah', Decimal('59.94')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Kursk', Decimal('59.94')),
#  ('BACKLASH UNDEFEATED', 3.0, 'London', Decimal('59.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Elista', Decimal('53.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Escobar', Decimal('53.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Loja', Decimal('59.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Omdurman', Decimal('53.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Pontianak', Decimal('53.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Tarlac', Decimal('47.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Uijongbu', Decimal('35.94')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Uttarpara-Kotrung', Decimal('59.94')),
#  ('BADMAN DAWN', 2.0, 'Huixquilucan', Decimal('17.94')),
#  ('BADMAN DAWN', 2.0, 'Rizhao', Decimal('17.94')),
#  ('BADMAN DAWN', 2.0, 'Tanza', Decimal('35.94')),
#  ('BADMAN DAWN', 2.0, 'Tieli', Decimal('29.94')),
#  ('BADMAN DAWN', 3.0, 'Alvorada', Decimal('17.94')),
#  ('BADMAN DAWN', 3.0, 'Fukuyama', Decimal('17.94')),
#  ('BADMAN DAWN', 3.0, 'Hami', Decimal('35.94')),
#  ('BADMAN DAWN', 3.0, 'Najafabad', Decimal('17.94')),
#  ('BADMAN DAWN', 3.0, 'Simferopol', Decimal('23.94')),
#  ('BADMAN DAWN', 3.0, 'Soshanguve', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Abha', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Balikesir', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Beira', Decimal('29.94')),
#  ('BADMAN DAWN', 4.0, 'Citt del Vaticano', Decimal('23.94')),
#  ('BADMAN DAWN', 4.0, 'Oyo', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Ozamis', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Pak Kret', Decimal('41.88')),
#  ('BADMAN DAWN', 4.0, 'Serpuhov', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Siliguri (Shiliguri)', Decimal('17.94')),
#  ('BADMAN DAWN', 4.0, 'Zaoyang', Decimal('23.94')),
#  ('BAKED CLEOPATRA', 1.0, 'Okayama', Decimal('17.94')),
#  ('BAKED CLEOPATRA', 2.0, 'Tarsus', Decimal('17.94')),
#  ('BAKED CLEOPATRA', 3.0, 'Garden Grove', Decimal('35.94')),
#  ('BAKED CLEOPATRA', 3.0, 'Hiroshima', Decimal('23.94')),
#  ('BAKED CLEOPATRA', 3.0, 'Madiun', Decimal('17.94')),
#  ('BAKED CLEOPATRA', 3.0, 'Santa Rosa', Decimal('41.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Acua', Decimal('29.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Bergamo', Decimal('41.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Gandhinagar', Decimal('17.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Hodeida', Decimal('41.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Ourense (Orense)', Decimal('41.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Phnom Penh', Decimal('17.94')),
#  ('BAKED CLEOPATRA', 4.0, 'San Miguel de Tucumn', Decimal('17.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Valencia', Decimal('47.94')),
#  ('BAKED CLEOPATRA', 4.0, 'Vila Velha', Decimal('47.94')),
#  ('BAKED CLEOPATRA', 5.0, 'Haiphong', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 1.0, 'Witten', Decimal('41.94')),
#  ('BALLOON HOMEWARD', 2.0, 'Botosani', Decimal('23.94')),
#  ('BALLOON HOMEWARD', 2.0, 'Datong', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 2.0, 'Pak Kret', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 2.0, 'Plock', Decimal('23.94')),
#  ('BALLOON HOMEWARD', 2.0, 'Vitria de Santo Anto', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Allende', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Araatuba', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Binzhou', Decimal('41.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Cianjur', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Fuyu', Decimal('23.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Livorno', Decimal('23.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Salzburg', Decimal('41.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Udaipur', Decimal('35.94')),
#  ('BALLOON HOMEWARD', 3.0, 'Zaoyang', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Beira', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Beni-Mellal', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Bucuresti', Decimal('41.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Junan', Decimal('29.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Roanoke', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Yantai', Decimal('23.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Yerevan', Decimal('17.94')),
#  ('BALLOON HOMEWARD', 4.0, 'Yinchuan', Decimal('41.94')),
#  ('BALLROOM MOCKINGBIRD', 1.0, 'Valparai', Decimal('5.94')),
#  ('BALLROOM MOCKINGBIRD', 2.0, 'Compton', Decimal('5.94')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Cam Ranh', Decimal('5.94')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Omiya', Decimal('5.94')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Tychy', Decimal('11.94')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Effon-Alaiye', Decimal('5.94')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Malm', Decimal('17.94')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Tarsus', Decimal('5.94')),
#  ('BANG KWAI', 2.0, 'Torren', Decimal('23.94')),
#  ('BANG KWAI', 3.0, 'Coatzacoalcos', Decimal('23.94')),
#  ('BANG KWAI', 3.0, 'Pontianak', Decimal('17.94')),
#  ('BANG KWAI', 4.0, 'Boa Vista', Decimal('17.94')),
#  ('BANG KWAI', 4.0, 'Nagaon', Decimal('17.94')),
#  ('BANG KWAI', 4.0, 'Shikarpur', Decimal('17.94')),
#  ('BANG KWAI', 5.0, 'Taizz', Decimal('17.94')),
#  ('BANGER PINOCCHIO', 1.0, 'Shubra al-Khayma', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 1.0, 'Tonghae', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 2.0, 'Cabuyao', Decimal('11.94')),
#  ('BANGER PINOCCHIO', 2.0, 'Cavite', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 2.0, 'Munger (Monghyr)', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 2.0, 'Novoterkassk', Decimal('17.94')),
#  ('BANGER PINOCCHIO', 2.0, 'Siliguri (Shiliguri)', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Abha', Decimal('11.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Binzhou', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Emeishan', Decimal('17.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Kaduna', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Ocumare del Tuy', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Simferopol', Decimal('29.94')),
#  ('BANGER PINOCCHIO', 3.0, 'Tama', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Almirante Brown', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Bamenda', Decimal('17.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Jakarta', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Jinchang', Decimal('29.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Katihar', Decimal('23.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Tychy', Decimal('17.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Vancouver', Decimal('5.94')),
#  ('BANGER PINOCCHIO', 4.0, 'Vicente Lpez', Decimal('5.94')),
#  ('BARBARELLA STREETCAR', 1.0, 'Alvorada', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 1.0, 'Bucuresti', Decimal('35.94')),
#  ('BARBARELLA STREETCAR', 1.0, 'Kamakura', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 2.0, 'Ashdod', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 2.0, 'Cuernavaca', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 2.0, 'Ezeiza', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 2.0, 'Graz', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 2.0, 'Uruapan', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Abha', Decimal('29.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Bellevue', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Gandhinagar', Decimal('23.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Huixquilucan', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Ikerre', Decimal('23.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Maring', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Richmond Hill', Decimal('29.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Sal', Decimal('35.94')),
#  ('BARBARELLA STREETCAR', 3.0, 'Yuncheng', Decimal('35.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Hubli-Dharwad', Decimal('23.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Meixian', Decimal('35.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Miraj', Decimal('23.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Moscow', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Niznekamsk', Decimal('23.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Qomsheh', Decimal('23.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'South Hill', Decimal('17.94')),
#  ('BARBARELLA STREETCAR', 4.0, 'Tabriz', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 1.0, 'Juazeiro do Norte', Decimal('41.94')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Halifax', Decimal('29.94')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Jelets', Decimal('23.94')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Madiun', Decimal('23.94')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Basel', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Fukuyama', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Halisahar', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Kuwana', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Pontianak', Decimal('35.94')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Torren', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Adoni', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Guadalajara', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Haiphong', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Jastrzebie-Zdrj', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Kitwe', Decimal('29.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Le Mans', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Ljubertsy', Decimal('17.94')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'al-Manama', Decimal('17.94')),
#  ('BASIC EASY', 1.0, 'Tianjin', Decimal('17.94')),
#  ('BASIC EASY', 2.0, 'Shimoga', Decimal('17.94')),
#  ('BASIC EASY', 2.0, 'Sincelejo', Decimal('17.94')),
#  ('BASIC EASY', 3.0, 'Akishima', Decimal('23.94')),
#  ('BASIC EASY', 3.0, 'Bayugan', Decimal('35.94')),
#  ('BASIC EASY', 3.0, 'Escobar', Decimal('47.94')),
#  ('BASIC EASY', 3.0, 'Jurez', Decimal('23.94')),
#  ('BASIC EASY', 3.0, 'Konotop', Decimal('17.94')),
#  ('BASIC EASY', 3.0, 'Santiago de Compostela', Decimal('17.94')),
#  ('BASIC EASY', 3.0, 'Vancouver', Decimal('35.94')),
#  ('BASIC EASY', 3.0, 'Ziguinchor', Decimal('17.94')),
#  ('BASIC EASY', 4.0, 'Batman', Decimal('23.94')),
#  ('BASIC EASY', 4.0, 'Haining', Decimal('17.94')),
#  ('BASIC EASY', 4.0, 'Imus', Decimal('17.94')),
#  ('BASIC EASY', 4.0, 'Lubumbashi', Decimal('41.94')),
#  ('BASIC EASY', 4.0, 'Novi Sad', Decimal('17.94')),
#  ('BASIC EASY', 4.0, 'Pjatigorsk', Decimal('17.94')),
#  ('BASIC EASY', 4.0, 'Robamba', Decimal('23.94')),
#  ('BASIC EASY', 4.0, 'Santa Rosa', Decimal('47.94')),
#  ('BASIC EASY', 4.0, 'Simferopol', Decimal('41.94')),
#  ('BASIC EASY', 5.0, 'Laohekou', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 1.0, 'Almirante Brown', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 1.0, 'Katihar', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Cuautla', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Kilis', Decimal('29.94')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Novoterkassk', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Bijapur', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Caracas', Decimal('29.94')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Crdoba', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Hsichuh', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Quilmes', Decimal('23.94')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Sterling Heights', Decimal('35.94')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Kingstown', Decimal('35.94')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Lungtan', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Mysore', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Pathankot', Decimal('35.94')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Ruse', Decimal('17.94')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Xiangtan', Decimal('17.94')),
#  ('BEAR GRACELAND', 1.0, 'Pingxiang', Decimal('23.94')),
#  ('BEAR GRACELAND', 1.0, 'Tabuk', Decimal('41.94')),
#  ('BEAR GRACELAND', 1.0, 'Uijongbu', Decimal('17.94')),
#  ('BEAR GRACELAND', 2.0, 'Bchar', Decimal('17.94')),
#  ('BEAR GRACELAND', 2.0, 'Bhopal', Decimal('17.94')),
#  ('BEAR GRACELAND', 2.0, 'Nakhon Sawan', Decimal('35.94')),
#  ('BEAR GRACELAND', 2.0, 'South Hill', Decimal('17.94')),
#  ('BEAR GRACELAND', 3.0, 'Angra dos Reis', Decimal('47.94')),
#  ('BEAR GRACELAND', 3.0, 'Juazeiro do Norte', Decimal('47.94')),
#  ('BEAR GRACELAND', 3.0, 'Olomouc', Decimal('23.94')),
#  ('BEAR GRACELAND', 3.0, 'Pune', Decimal('35.94')),
#  ('BEAR GRACELAND', 3.0, 'Rio Claro', Decimal('29.94')),
#  ('BEAR GRACELAND', 3.0, 'Robamba', Decimal('41.94')),
#  ('BEAR GRACELAND', 3.0, 'Tiefa', Decimal('23.94')),
#  ('BEAR GRACELAND', 4.0, 'Addis Abeba', Decimal('17.94')),
#  ('BEAR GRACELAND', 4.0, 'Ahmadnagar', Decimal('41.94')),
#  ('BEAR GRACELAND', 4.0, 'Bhilwara', Decimal('17.94')),
#  ('BEAR GRACELAND', 4.0, 'Czestochowa', Decimal('29.94')),
#  ('BEAR GRACELAND', 4.0, 'Lapu-Lapu', Decimal('29.94')),
#  ('BEAR GRACELAND', 4.0, 'Liaocheng', Decimal('47.94')),
#  ('BEAR GRACELAND', 4.0, 'Mardan', Decimal('17.94')),
#  ('BEAR GRACELAND', 4.0, 'Shenzhen', Decimal('17.94')),
#  ('BEAST HUNCHBACK', 1.0, 'Jinzhou', Decimal('41.94')),
#  ('BEAST HUNCHBACK', 2.0, 'Faaa', Decimal('29.94')),
#  ('BEAST HUNCHBACK', 2.0, 'Nanyang', Decimal('29.94')),
#  ('BEAST HUNCHBACK', 3.0, 'Duisburg', Decimal('29.94')),
#  ('BEAST HUNCHBACK', 3.0, 'Omiya', Decimal('65.94')),
#  ('BEAST HUNCHBACK', 3.0, 'Sincelejo', Decimal('53.94')),
#  ('BEAST HUNCHBACK', 4.0, 'Chandrapur', Decimal('29.94')),
#  ('BEAST HUNCHBACK', 4.0, 'Chiayi', Decimal('29.94')),
#  ('BEAST HUNCHBACK', 4.0, 'Guadalajara', Decimal('65.94')),
#  ('BEAST HUNCHBACK', 4.0, 'Kolpino', Decimal('47.94')),
#  ('BEAST HUNCHBACK', 4.0, 'Zaoyang', Decimal('35.94')),
#  ('BEAUTY GREASE', 1.0, 'Denizli', Decimal('41.94')),
#  ('BEAUTY GREASE', 2.0, 'Barcelona', Decimal('29.94')),
#  ('BEAUTY GREASE', 2.0, 'Daugavpils', Decimal('53.94')),
#  ('BEAUTY GREASE', 2.0, 'Huixquilucan', Decimal('29.94')),
#  ('BEAUTY GREASE', 3.0, 'Davao', Decimal('29.94')),
#  ('BEAUTY GREASE', 3.0, 'Firozabad', Decimal('29.94')),
#  ('BEAUTY GREASE', 3.0, 'Jaffna', Decimal('29.94')),
#  ('BEAUTY GREASE', 3.0, 'Kursk', Decimal('53.94')),
#  ('BEAUTY GREASE', 3.0, 'Lancaster', Decimal('53.94')),
#  ('BEAUTY GREASE', 3.0, 'Mwene-Ditu', Decimal('35.94')),
#  ('BEAUTY GREASE', 3.0, 'Richmond Hill', Decimal('29.94')),
#  ('BEAUTY GREASE', 3.0, 'Ziguinchor', Decimal('29.94')),
#  ('BEAUTY GREASE', 4.0, 'Acua', Decimal('29.94')),
#  ('BEAUTY GREASE', 4.0, 'Arlington', Decimal('29.94')),
#  ('BEAUTY GREASE', 4.0, 'Bhopal', Decimal('29.94')),
#  ('BEAUTY GREASE', 4.0, 'Dhule (Dhulia)', Decimal('47.94')),
#  ('BEAUTY GREASE', 4.0, 'Hsichuh', Decimal('29.94')),
#  ('BEAUTY GREASE', 4.0, 'Kamarhati', Decimal('41.94')),
#  ('BEAUTY GREASE', 4.0, 'Nezahualcyotl', Decimal('41.94')),
#  ('BEAUTY GREASE', 4.0, 'Omdurman', Decimal('29.94')),
#  ('BEAUTY GREASE', 4.0, 'Syktyvkar', Decimal('35.94')),
#  ('BEAUTY GREASE', 4.0, 'Zhezqazghan', Decimal('29.94')),
#  ('BED HIGHBALL', 3.0, 'Bhimavaram', Decimal('23.94')),
#  ('BED HIGHBALL', 3.0, 'Liaocheng', Decimal('17.94')),
#  ('BED HIGHBALL', 3.0, 'San Miguel de Tucumn', Decimal('17.94')),
#  ('BED HIGHBALL', 4.0, 'Iligan', Decimal('17.94')),
#  ('BED HIGHBALL', 4.0, 'Kursk', Decimal('35.94')),
#  ('BED HIGHBALL', 4.0, 'Santo Andr', Decimal('35.94')),
#  ('BEDAZZLED MARRIED', 1.0, 'Angra dos Reis', Decimal('11.94')),
#  ('BEDAZZLED MARRIED', 2.0, 'Balurghat', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 2.0, 'Myingyan', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 3.0, 'Baybay', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 3.0, 'Duisburg', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 3.0, 'Le Mans', Decimal('11.94')),
#  ('BEDAZZLED MARRIED', 3.0, 'Naju', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 3.0, 'San Felipe de Puerto Plata', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 4.0, 'Binzhou', Decimal('11.94')),
#  ('BEDAZZLED MARRIED', 4.0, 'Naju', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 4.0, 'Serpuhov', Decimal('5.94')),
#  ('BEDAZZLED MARRIED', 4.0, 'Shanwei', Decimal('11.94')),
#  ...]

# %% [markdown]
# # Conclusion

# %% [markdown]
# We were able to show that:
# * The star schema is easier to understand and write queries against.
# * Queries with a star schema are more performant.
